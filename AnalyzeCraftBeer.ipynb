# %%
#https://bit.ly/2Lw2ynG

# %%
import csv
with open('data/beers.csv',newline='') as f:
    reader = csv.reader(f)
    beers = list(reader)
f.close()

# %%
beers[0]
# Out:
# ['', 'abv', 'ibu', 'id', 'name', 'style', 'brewery_id', 'ounces']

# %%
beers[1:]
# Out:
# [['0', '0.05', '', '1436', 'Pub Beer', 'American Pale Lager', '408', '12.0'],
#  ['1',
#   '0.066',
#   '',
#   '2265',
#   "Devil's Cup",
#   'American Pale Ale (APA)',
#   '177',
#   '12.0'],
#  ['2',
#   '0.071',
#   '',
#   '2264',
#   'Rise of the Phoenix',
#   'American IPA',
#   '177',
#   '12.0'],
#  ['3',
#   '0.09',
#   '',
#   '2263',
#   'Sinister',
#   'American Double / Imperial IPA',
#   '177',
#   '12.0'],
#  ['4', '0.075', '', '2262', 'Sex and Candy', 'American IPA', '177', '12.0'],
#  ['5', '0.077', '', '2261', 'Black Exodus', 'Oatmeal Stout', '177', '12.0'],
#  ['6',
#   '0.045',
#   '',
#   '2260',
#   'Lake Street Express',
#   'American Pale Ale (APA)',
#   '177',
#   '12.0'],
#  ['7', '0.065', '', '2259', 'Foreman', 'American Porter', '177', '12.0'],
#  ['8', '0.055', '', '2258', 'Jade', 'American Pale Ale (APA)', '177', '12.0'],
#  ['9',
#   '0.086',
#   '',
#   '2131',
#   'Cone Crusher',
#   'American Double / Imperial IPA',
#   '177',
#   '12.0'],
# ...

# %%
with open('data/beers.csv',newline='') as f:
    reader = csv.reader(f)
    breweries = list(reader)
f.close()

# %%
beer_details ={
    "raw_data": beers,
    "columns": beers[0],
    "data": beers[1:]
}

brewery_details = {
    "raw_data":breweries,
    "columns": breweries[0],
    "data":breweries[1:]
}

# %%
brewery_details["columns"]
# Out:
# ['', 'abv', 'ibu', 'id', 'name', 'style', 'brewery_id', 'ounces']

# %%
brewery_details["columns"][0] = "brewery_id"
brewery_details["columns"][0]
# Out:
# 'brewery_id'

# %%
datasets = {
    "beer":beer_details,
    "breweries":brewery_details
}

# %%
datasets["beer"]["columns"]
# Out:
# ['', 'abv', 'ibu', 'id', 'name', 'style', 'brewery_id', 'ounces']

# %%
data["beer_data"][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-db710cd366d2> in <module>
# ----> 1 data["beer_data"][0]
#
# KeyError: 0
